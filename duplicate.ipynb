# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
api_key = 'o39LN2yUm0OXvxj4cwjj4ektfPDvWDJpf5fRvqNLQNkvitaMNeNDrKZOt1oaGKcM4ihQcGiUca3QXCr4DeA0X_x-P4kiAnT8OIOy2UjZJsRIg7855OK0aKz1AlvSX3Yx'

# %%
business_endpoint = 'https://api.yelp.com/v3/businesses/search'

# %%
header_category = {'Authorization': 'bearer %s' % api_key}

# %%
params_offset = 50

# %%
params_category_music = {'location': 'East Nashville', 'limit': 50, 'categories': 'bars', 'offset': params_offset}

# %%
response_business_music = requests.get(url = business_endpoint, params = params_category_music, headers = header_category)

# %%
response_business_music.json()
# Out:
# {'error': {'code': 'VALIDATION_ERROR',
#   'description': '39050 is greater than the maximum of 1000',
#   'field': 'offset',
#   'instance': 39050}}

# %%
def extract_music_info(music):
    categories =  [a['title'] for a in music['categories']]
    ratings = music['rating']
    name = music['name']
    address = music['location']['display_address']
    latitude = music['coordinates']['latitude']
    longitude = music['coordinates']['longitude']
    try:
        price = music['price']
    except:
        price = 'no price'
    zip_code = music['location']['zip_code']
    is_closed = music['is_closed']
    output_dict_music = { 
                   'categories': categories,   
                   'ratings': ratings,
                   'name': name,
                   'display_address': address,
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code,
                   'is_closed': is_closed}

    return output_dict_music

# %%
music_list = []
for increment in range(0, 1000, 50) : 
    response_business_music = requests.get(url = business_endpoint, params = params_category_music, headers = header_category)
    for music_data in response_business_music.json()['business']:
        music_dict = extract_music_info(music_data)
        music_list.append(music_dict)
        params_offset += 50
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-cd751f653b9e> in <module>
#       2 for increment in range(0, 1000, 50) :
#       3     response_business_music = requests.get(url = business_endpoint, params = params_category_music, headers = header_category)
# ----> 4     for music_data in response_business_music.json()['business']:
#       5         music_dict = extract_music_info(music_data)
#       6         music_list.append(music_dict)
#
# KeyError: 'business'

# %%
music_venues_nash = pd.DataFrame(music_list)
music_venues_nash
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
music_venues_nash['display_address'] = music_venues_nash['display_address'].apply(lambda x: x[0] + x[1])
music_venues_nash
# Out:
#                                         categories  ratings  \
# 0                             [Bars, Music Venues]      3.0
# 1                        [Dive Bars, Music Venues]      3.0
# 2            [Hot Dogs, Sports Bars, Music Venues]      3.0
# 3                                   [Music Venues]      4.0
# 4    [Music Venues, American (New), Cocktail Bars]      4.5
# ..                                             ...      ...
# 775                   [Music Venues, Coffee & Tea]      4.0
# 776                                 [Music Venues]      3.0
# 777                                 [Music Venues]      1.0
# 778         [Music Venues, Juice Bars & Smoothies]      1.0
# 779                                 [Music Venues]      1.0
#
#                                     name display_address   latitude  \
# 0               Music City Bar and Grill              24  36.219441
# 1                              Big Shotz              11  36.162327
# 2                       DawgHouse Saloon              15  36.153147
# 3                          The High Watt              1   36.152824
# 4                        Jane’s Hideaway              20  36.164521
# ..                                   ...             ...        ...
# 775                            Curb Cafe              20  36.132515
# 776  Vanderbilt Univ Langford Auditorium              1   36.143219
# 777               Nashville Center Stage              51  36.153250
# 778                         The Platform              15  36.139003
# 779                  Time Travelers Cafe              21  36.152020
#
#      longitude     price zip_code  is_closed
# 0   -86.698046        $$    37214      False
# 1   -86.775764         $    37201      False
# 2   -86.790335        $$    37203      False
# 3   -86.780319         $    37203      False
# 4   -86.778329  no price    37201      False
# ..         ...       ...      ...        ...
# 775 -86.795213         $    37212      False
# 776 -86.804222         $    37240      False
# 777 -86.778990  no price    37203      False
# 778 -86.759543  no price    37210      False
# 779 -86.804970  no price    37203      False
#
# [780 rows x 9 columns]

# %%
music_venues_nash['categories'] = music_venues_nash['categories'].apply(lambda x: x[0])
music_venues_nash
# Out:
#                         categories  ratings  \
# 0                     Music Venues      4.0
# 1                             Bars      4.0
# 2                     Music Venues      3.5
# 3                          Lounges      4.5
# 4                   American (New)      3.5
# ..                             ...      ...
# 795                   Music Venues      3.0
# 796                   Music Venues      1.0
# 797                   Music Venues      1.0
# 798                   Music Venues      1.0
# 799  Recording & Rehearsal Studios      1.0
#
#                                     name  \
# 0                      The Bluebird Cafe
# 1                              The Local
# 2                   BB King's Blues Club
# 3                 Analog at Hutton Hotel
# 4                       Commodore Grille
# ..                                   ...
# 795  Vanderbilt Univ Langford Auditorium
# 796               Nashville Center Stage
# 797                         The Platform
# 798                  Time Travelers Cafe
# 799                         South By Sea
#
#                             display_address   latitude  longitude     price  \
# 0    4104 Hillsboro PikeNashville, TN 37215  36.102200 -86.817000        $$
# 1         110 28th Ave NNashville, TN 37203  36.145910 -86.812620        $$
# 2          152 2nd Ave NNashville, TN 37201  36.163349 -86.775960        $$
# 3         1808 W End AveNashville, TN 37203  36.152860 -86.797080        $$
# 4         2613 W End AveNashville, TN 37203  36.144580 -86.810830        $$
# ..                                      ...        ...        ...       ...
# 795        1 Garland AveNashville, TN 37240  36.143219 -86.804222         $
# 796        514 8th Ave SNashville, TN 37203  36.153250 -86.778990  no price
# 797       1500 2nd Ave SNashville, TN 37210  36.139003 -86.759543  no price
# 798       212 Louise AveNashville, TN 37203  36.152020 -86.804970  no price
# 799        1313 Jewel StNashville, TN 37207  36.194960 -86.754050  no price
#
#     zip_code  is_closed
# 0      37215      False
# 1      37203      False
# 2      37201      False
# 3      37203      False
# 4      37203      False
# ..       ...        ...
# 795    37240      False
# 796    37203      False
# 797    37210      False
# 798    37203      False
# 799    37207      False
#
# [800 rows x 9 columns]

# %%
music_venues_nash.to_csv(r'C:\Users\mia\Desktop\nss\projects\capstone\data\nash_venues.csv', index = False)
