# %%
import pandas as pd

# %%
venues = pd.read_csv('./data/excel_indie_venues.csv', usecols = ['name', 'capacity', 'ages', 'genres_extract', 'outdoor_performance_space', 'lgbt_friendly'])
venues
# Out:
#                               name                        capacity ages  \
# 0              The Bluebird Cafe\n                             100  All
# 1             The 5 Spot\n\n\n\n\n                             180  21+
# 2         Mercy Lounge\n\n\n\n\n\n                             500  18+
# 3                      The Local\n                             200  21+
# 4                The Crying Wolf\n  50 (back room), 96 (main bar).  21+
# ..                             ...                             ...  ...
# 100           Drkmttr Collective\n                             NaN  All
# 101  Kid Rock's Big Ass Honky Tonk      2000 between all 5 floors.  All
# 102         The Rhinestone Stage\n       100 seated, 125 standing.  All
# 103              6th and Peabody\n       500 inside, 2000 outside.  All
# 104              Redneck Riviera\n                             NaN  All
#
#                                         genres_extract  \
# ...

# %%
venues['name'] = venues['name'].str.replace('\n', '')
venues
# Out:
#                               name                        capacity ages  \
# 0                The Bluebird Cafe                             100  All
# 1                       The 5 Spot                             180  21+
# 2                     Mercy Lounge                             500  18+
# 3                        The Local                             200  21+
# 4                  The Crying Wolf  50 (back room), 96 (main bar).  21+
# ..                             ...                             ...  ...
# 100             Drkmttr Collective                             NaN  All
# 101  Kid Rock's Big Ass Honky Tonk      2000 between all 5 floors.  All
# 102           The Rhinestone Stage       100 seated, 125 standing.  All
# 103                6th and Peabody       500 inside, 2000 outside.  All
# 104                Redneck Riviera                             NaN  All
#
#                                         genres_extract  \
# ...

# %%
venues['genres_extract'] = venues['genres_extract'].str.replace('\n', '')
venues
# Out:
#                               name                        capacity ages  \
# 0                The Bluebird Cafe                             100  All
# 1                       The 5 Spot                             180  21+
# 2                     Mercy Lounge                             500  18+
# 3                        The Local                             200  21+
# 4                  The Crying Wolf  50 (back room), 96 (main bar).  21+
# ..                             ...                             ...  ...
# 100             Drkmttr Collective                             NaN  All
# 101  Kid Rock's Big Ass Honky Tonk      2000 between all 5 floors.  All
# 102           The Rhinestone Stage       100 seated, 125 standing.  All
# 103                6th and Peabody       500 inside, 2000 outside.  All
# 104                Redneck Riviera                             NaN  All
#
#                                         genres_extract  \
# ...

# %%
venues.to_csv(r'C:\Users\mia\Desktop\nss\projects\capstone\data\indie_venues.csv', index = False)
