# %%
import pandas as pd

# %%
indie_venues = pd.read_csv('./data/indie_venues.csv')
# Out:
#                                                   Name  \
# 0                                  The Bluebird Cafe\n
# 1                                 The 5 Spot\n\n\n\n\n
# 2                             Mercy Lounge\n\n\n\n\n\n
# 3                                          The Local\n
# 4                                    The Crying Wolf\n
# ..                                                 ...
# 105                          Kid Rock's Big Honky Tonk
# 106  The Rhinestone Stage\nMusic VenueMuseum\n\n\n\...
# 107  6th and Peabody\nMusic VenueOutdoor Performanc...
# 108  Redneck Riviera\nMusic VenueBarRestaurant\n\n\...
# 109  Hard Truth Hills\nMusic VenueRestaurantBrewery...
#
#                            Capacity Ages  \
# 0                               100  All
# 1                               180  21+
# 2                               500  18+
# 3                               200  21+
# 4    50 (back room), 96 (main bar).  21+
# ..                              ...  ...
# ...
