# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
api_key = 'o39LN2yUm0OXvxj4cwjj4ektfPDvWDJpf5fRvqNLQNkvitaMNeNDrKZOt1oaGKcM4ihQcGiUca3QXCr4DeA0X_x-P4kiAnT8OIOy2UjZJsRIg7855OK0aKz1AlvSX3Yx'

# %%
business_endpoint = 'https://api.yelp.com/v3/businesses/search'

# %%
header_category = {'Authorization': 'bearer %s' % api_key}

# %%
#params_offset = 50

# %%
params_category_music = {'location': 'Nashville', 'limit': 50, 'categories': 'musicvenues'}

# %%
response_business_music= requests.get(url = business_endpoint, params = params_category_music, headers = header_category)

# %%
response_business_music.json()
# Out:
# {'businesses': [{'id': 'tELoGj2QJYYFQ1jo_XXbpA',
#    'alias': 'roberts-western-world-nashville',
#    'name': "Robert's Western World",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k1FNN4ziVsCjb02eddD_pA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roberts-western-world-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 783,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.161029, 'longitude': -86.778007},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '416 Broadway',
#     'address2': 'Ste B',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['416 Broadway', 'Ste B', 'Nashville, TN 37203']},
#    'phone': '+16152449552',
#    'display_phone': '(615) 244-9552',
#    'distance': 2603.472879326756},
#   {'id': '4Cal2AE6cr7m6nL20Rz2kQ',
#    'alias': 'ryman-auditorium-nashville',
#    'name': 'Ryman Auditorium',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/a4WFzIz1rE-Mw-je6ftVcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ryman-auditorium-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 543,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'historicaltours', 'title': 'Historical Tours'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.1612239, 'longitude': -86.7787392},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '116 5th Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37219',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['116 5th Ave N', 'Nashville, TN 37219']},
#    'phone': '+16158893060',
#    'display_phone': '(615) 889-3060',
#    'distance': 2631.9474894935192},
#   {'id': 'KqF1W-GxTAnOZtcMNS5Wiw',
#    'alias': 'belcourt-theatre-nashville',
#    'name': 'Belcourt Theatre',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CgFVVddQudCW9ljXAmdHYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/belcourt-theatre-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 208,
#    'categories': [{'alias': 'movietheaters', 'title': 'Cinema'},
#     {'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.136915, 'longitude': -86.801515},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2102 Belcourt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37212',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2102 Belcourt Ave', 'Nashville, TN 37212']},
#    'phone': '+16158463150',
#    'display_phone': '(615) 846-3150',
#    'distance': 2329.798172881534},
#   {'id': 'DPtdBtLp6ng9cAB9_rzB6g',
#    'alias': 'tootsies-orchid-lounge-nashville',
#    'name': "Tootsie's Orchid Lounge",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8OzHNAs5gUGCYhU_x2SGTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tootsies-orchid-lounge-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 891,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.1609, 'longitude': -86.77828},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '422 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['422 Broadway', 'Nashville, TN 37203']},
#    'phone': '+16157260463',
#    'display_phone': '(615) 726-0463',
#    'distance': 2578.1389524117635},
#   {'id': 'd-9vXGzbI2eZAJWKb06h3A',
#    'alias': 'the-station-inn-nashville',
#    'name': 'The Station Inn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2Gyacq86_ZrZUte-KLZnOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-station-inn-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 192,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.15258, 'longitude': -86.78444},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '402 12th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['402 12th Ave S', 'Nashville, TN 37203']},
#    'phone': '+16152553307',
#    'display_phone': '(615) 255-3307',
#    'distance': 1837.3307528450355},
#   {'id': 'ZNxFIwgPnmLu6ouQPPpR_Q',
#    'alias': 'sambuca-nashville',
#    'name': 'Sambuca',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qPBWCvop-S8MRm1YJqeiQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sambuca-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 604,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.1518014103093,
#     'longitude': -86.7844176292419},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '601 12th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['601 12th Ave S', 'Nashville, TN 37203']},
#    'phone': '+16152482888',
#    'display_phone': '(615) 248-2888',
#    'distance': 1760.2756977616352},
#   {'id': 'BWPokhrYnWdfxdaUaM6l9Q',
#    'alias': 'nashville-symphony-nashville-2',
#    'name': 'Nashville Symphony',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WWJOOHoMwjsWXqlI4hqIjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nashville-symphony-nashville-2?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 105,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'theater', 'title': 'Performing Arts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.1599355657848,
#     'longitude': -86.7759658782959},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1 Symphony Pl',
#     'address2': '',
#     'address3': 'Schermerhorn Symphony Center',
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1 Symphony Pl',
#      'Schermerhorn Symphony Center',
#      'Nashville, TN 37201']},
#    'phone': '+16156876400',
#    'display_phone': '(615) 687-6400',
#    'distance': 2472.996841912683},
#   {'id': 'Cs0adaMTxJWTDSzuQ3vheg',
#    'alias': 'listening-room-cafe-nashville',
#    'name': 'Listening Room Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/THmDF2jIqH9FE4qJhpn-Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/listening-room-cafe-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 515,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.1536701707908,
#     'longitude': -86.7723606232499},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '618 4th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37210',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['618 4th Ave S', 'Nashville, TN 37210']},
#    'phone': '+16152593600',
#    'display_phone': '(615) 259-3600',
#    'distance': 1798.3940090230133},
#   {'id': 'sO1OD0SZkXXPtIXj2cS4oA',
#    'alias': 'the-stage-on-broadway-nashville-2',
#    'name': 'The Stage On Broadway',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kdPBlzkNM0lTOcRI87KApA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-stage-on-broadway-nashville-2?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 373,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.16111, 'longitude': -86.777898},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '412 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['412 Broadway', 'Nashville, TN 37203']},
#    'phone': '+16157260504',
#    'display_phone': '(615) 726-0504',
#    'distance': 2612.048175001567},
#   {'id': '6p07zfmJWvytr0paqpyvbg',
#    'alias': 'laylas-honky-tonk-nashville',
#    'name': "Layla's Honky Tonk",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/upWWz-ecUe1FCaXoG0Ph_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laylas-honky-tonk-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 180,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.16097, 'longitude': -86.77813},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '418 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['418 Broadway', 'Nashville, TN 37203']},
#    'phone': '+16157262799',
#    'display_phone': '(615) 726-2799',
#    'distance': 2592.1046792630013},
#   {'id': 'FeCkEyoGHVAR7KzrEX-uMA',
#    'alias': 'legends-corner-nashville',
#    'name': 'Legends Corner',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qu1eB9PFfTRtzNj-IkHD8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/legends-corner-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 221,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.1607004, 'longitude': -86.7782313},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '428 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['428 Broadway', 'Nashville, TN 37203']},
#    'phone': '+16152486334',
#    'display_phone': '(615) 248-6334',
#    'distance': 2582.6095479247833},
#   {'id': 'maOMGu_2dSHKydBgZdTsvQ',
#    'alias': 'wildhorse-saloon-nashville',
#    'name': 'Wildhorse Saloon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JmPFsc6ecasLg9oGProBZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wildhorse-saloon-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 524,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.16275, 'longitude': -86.7752},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '120 2nd Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['120 2nd Ave N', 'Nashville, TN 37201']},
#    'phone': '+16159028200',
#    'display_phone': '(615) 902-8200',
#    'distance': 2787.508857247079},
#   {'id': 'Ns8vJxhsc5ygiX7Vff1bDQ',
#    'alias': 'rippys-bar-and-grill-nashville',
#    'name': "Rippy's Bar & Grill",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/20bnLxif2txSYAKzMwO1pA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rippys-bar-and-grill-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 844,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 36.160356928631,
#     'longitude': -86.7781391237071},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '429 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['429 Broadway', 'Nashville, TN 37203']},
#    'phone': '+16152447477',
#    'display_phone': '(615) 244-7477',
#    'distance': 2530.527625146957},
#   {'id': 'dzAV7NCPW7PYWLYqgPE_GQ',
#    'alias': 'the-sutler-nashville-3',
#    'name': 'The Sutler',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MWzldraGD76KfaxpXBGgGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sutler-nashville-3?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 347,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.1220773229965,
#     'longitude': -86.7751237066765},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2600 8th Ave S',
#     'address2': 'Ste 109',
#     'address3': None,
#     'city': 'Nashville',
#     'zip_code': '37204',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2600 8th Ave S', 'Ste 109', 'Nashville, TN 37204']},
#    'phone': '+16158406124',
#    'display_phone': '(615) 840-6124',
#    'distance': 1737.3290841382443},
#   {'id': 'KC4Eo1S3AMA2qk8ULiLEkg',
#    'alias': 'bridgestone-arena-nashville',
#    'name': 'Bridgestone Arena',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Xubilr3HKiXWXKVMC7cFZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bridgestone-arena-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 221,
#    'categories': [{'alias': 'stadiumsarenas', 'title': 'Stadiums & Arenas'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.1591434847322,
#     'longitude': -86.7785167695803},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '501 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['501 Broadway', 'Nashville, TN 37203']},
#    'phone': '+16157702000',
#    'display_phone': '(615) 770-2000',
#    'distance': 2399.79366177393},
#   {'id': 'DH-vk-XzWMT9rRLcbBbnUw',
#    'alias': 'whiskey-bent-saloon-nashville',
#    'name': 'Whiskey Bent Saloon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/60izY52rm1PWFEuGdEaVOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/whiskey-bent-saloon-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 162,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.16165, 'longitude': -86.77649},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '306 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37219',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['306 Broadway', 'Nashville, TN 37219']},
#    'phone': '+16154012580',
#    'display_phone': '(615) 401-2580',
#    'distance': 2665.196839473879},
#   {'id': 'cEb1xzZzp6b4TM-MrqxktQ',
#    'alias': 'bootleggers-inn-nashville-3',
#    'name': 'Bootleggers Inn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F1mPUDhdT6jHTnTL6qz--g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bootleggers-inn-nashville-3?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 114,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.1615777642899,
#     'longitude': -86.7753694443613},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '207 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['207 Broadway', 'Nashville, TN 37201']},
#    'phone': '+16154573960',
#    'display_phone': '(615) 457-3960',
#    'distance': 2655.297150466752},
#   {'id': 'kjhIbW8NKRvXmLDwz7lzhw',
#    'alias': 'margaritaville-nashville-nashville-4',
#    'name': 'Margaritaville - Nashville',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NvE8Mp4pAz2Mhs4xetckeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/margaritaville-nashville-nashville-4?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 498,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.16137, 'longitude': -86.77719},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '322 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['322 Broadway', 'Nashville, TN 37201']},
#    'phone': '+16152089080',
#    'display_phone': '(615) 208-9080',
#    'distance': 2637.614640783756},
#   {'id': 'hMLcTXMk6xif0qfBi8-8sw',
#    'alias': '3rd-and-lindsley-nashville',
#    'name': '3rd and Lindsley',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/52w57FGBs7Ay7KqvCjdFJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/3rd-and-lindsley-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 184,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.1523056, 'longitude': -86.7700653},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '816 3rd Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37210',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['816 3rd Ave S', 'Nashville, TN 37210']},
#    'phone': '+16152591597',
#    'display_phone': '(615) 259-1597',
#    'distance': 1689.2151356602826},
#   {'id': 'WrKt4zg__6UgwqqINcoiFw',
#    'alias': 'mercy-lounge-nashville',
#    'name': 'Mercy Lounge',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BG7rw-Cw5P2UloVkI9qKbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mercy-lounge-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 108,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.1528244018555,
#     'longitude': -86.7803192138672},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1 Cannery Row',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1 Cannery Row', 'Nashville, TN 37203']},
#    'phone': '+16152513020',
#    'display_phone': '(615) 251-3020',
#    'distance': 1755.2929818971456},
#   {'id': 'fy7kLejLjyVsbVycL6gqfQ',
#    'alias': 'tin-roof-broadway-nashville-4',
#    'name': 'Tin Roof Broadway',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vk83ETSa6Eo3zRTW59pkWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tin-roof-broadway-nashville-4?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 259,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.1613946655495,
#     'longitude': -86.7768571232193},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '316 Broadway Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['316 Broadway Ave', 'Nashville, TN 37201']},
#    'phone': '+16152424446',
#    'display_phone': '(615) 242-4446',
#    'distance': 2637.6700309098856},
#   {'id': '4lT3LIMRWCDrpxsjHWscIA',
#    'alias': 'paradise-park-trailer-resort-nashville',
#    'name': 'Paradise Park Trailer Resort',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-iUdBA-bsRL2nn_H1H8wQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paradise-park-trailer-resort-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 282,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.1606580178435,
#     'longitude': -86.7775782417335},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '411 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37246',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['411 Broadway', 'Nashville, TN 37246']},
#    'phone': '+16152511515',
#    'display_phone': '(615) 251-1515',
#    'distance': 2559.7224901989835},
#   {'id': 'pIvX_Kw4f82baMUhRO6WxQ',
#    'alias': 'kid-rocks-big-honky-tonk-and-rock-n-roll-steakhouse-nashville',
#    'name': "Kid Rock's Big Honky Tonk and Rock n' Roll Steakhouse",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IL1sEZOiL3YQZugHVK9Beg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kid-rocks-big-honky-tonk-and-rock-n-roll-steakhouse-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 313,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.161339, 'longitude': -86.77565},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '221 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['221 Broadway', 'Nashville, TN 37201']},
#    'phone': '+16152482706',
#    'display_phone': '(615) 248-2706',
#    'distance': 2628.745558831843},
#   {'id': 'efGqAYPCCxPvHPX3dCM8bQ',
#    'alias': 'tennessee-performing-arts-center-nashville-2',
#    'name': 'Tennessee Performing Arts Center',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LCvLbNMNw01m3e1Xs2EmZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tennessee-performing-arts-center-nashville-2?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 90,
#    'categories': [{'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.16437, 'longitude': -86.782409},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '505 Deaderick St',
#     'address2': '',
#     'address3': None,
#     'city': 'Nashville',
#     'zip_code': '37243',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['505 Deaderick St', 'Nashville, TN 37243']},
#    'phone': '+16157824040',
#    'display_phone': '(615) 782-4040',
#    'distance': 3029.6961958815555},
#   {'id': 'I3_iREO5YfeuuO2CkeHc9g',
#    'alias': 'the-5-spot-nashville',
#    'name': 'The 5 Spot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k4i3WMW-3pGqmOuSNtaUqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-5-spot-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 127,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.1783027648926,
#     'longitude': -86.7504348754883},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1006 Forrest Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37206',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1006 Forrest Ave', 'Nashville, TN 37206']},
#    'phone': '+16156509333',
#    'display_phone': '(615) 650-9333',
#    'distance': 5055.984743265706},
#   {'id': 't0FzBzAoqVpK5fNIGOPv-g',
#    'alias': 'dierks-bentleys-whiskey-row-nashville',
#    'name': "Dierks Bentley's Whiskey Row",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vrwnMAU0Qm99uBqmZK9tyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dierks-bentleys-whiskey-row-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 440,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.16116, 'longitude': -86.7774699},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '400 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['400 Broadway', 'Nashville, TN 37203']},
#    'phone': '+16292037822',
#    'display_phone': '(629) 203-7822',
#    'distance': 2617.2044876406744},
#   {'id': 'kcfBl1u4Zf-qppprSoa1FQ',
#    'alias': 'ascend-amphitheater-nashville',
#    'name': 'Ascend Amphitheater',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XhJBT-_GHGnyO4rIjk7iPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ascend-amphitheater-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 92,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.1598721570385,
#     'longitude': -86.771840267984},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '301 1st Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['301 1st Ave S', 'Nashville, TN 37201']},
#    'phone': '+16159999000',
#    'display_phone': '(615) 999-9000',
#    'distance': 2487.562817824729},
#   {'id': 'vpQWbT7ZKcHMVKxEVR8Cuw',
#    'alias': 'benchmark-bar-and-grill-nashville',
#    'name': 'Benchmark Bar & Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ApRhStBxQlVtFLZms_SqLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benchmark-bar-and-grill-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 108,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.162408, 'longitude': -86.775813},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '117 2nd Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['117 2nd Ave N', 'Nashville, TN 37201']},
#    'phone': '+16158527460',
#    'display_phone': '(615) 852-7460',
#    'distance': 2747.7161949357314},
#   {'id': 'wjGmBfeFrh71764EQcZzxg',
#    'alias': 'second-fiddle-nashville',
#    'name': 'Second Fiddle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A38J1koC_WC_kHV2okSfPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/second-fiddle-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 110,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.1609399, 'longitude': -86.7782},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '420 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['420 Broadway', 'Nashville, TN 37203']},
#    'phone': '+16152484818',
#    'display_phone': '(615) 248-4818',
#    'distance': 2577.138776667774},
#   {'id': 'eic2JlbB24qel-u9VG7PGA',
#    'alias': 'exit-in-nashville-2',
#    'name': 'EXIT/IN',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gUmMMpA1yA-1JEnCAH3xaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exit-in-nashville-2?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 91,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.151342, 'longitude': -86.8042755004958},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2208 Elliston Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37246',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2208 Elliston Pl', 'Nashville, TN 37246']},
#    'phone': '+16153213340',
#    'display_phone': '(615) 321-3340',
#    'distance': 2995.32663415718},
#   {'id': '42tur3_5JgqOU-5KoY-zHQ',
#    'alias': 'nashville-palace-nashville-3',
#    'name': 'Nashville Palace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/on5ohS-pj0kLm81aOKJyfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nashville-palace-nashville-3?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 165,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.2177276611328,
#     'longitude': -86.6982040405273},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2611 McGavock Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37214',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2611 McGavock Pike', 'Nashville, TN 37214']},
#    'phone': '+16158891540',
#    'display_phone': '(615) 889-1540',
#    'distance': 11284.099463796454},
#   {'id': '10KnzbTaz-Yq8wADXGuOlw',
#    'alias': 'alley-taps-nashville',
#    'name': 'Alley Taps',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YOWnBMH5zPqz8_ONaHQpCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alley-taps-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 64,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.163439, 'longitude': -86.778287},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '162 Printers Alley',
#     'address2': '',
#     'address3': None,
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['162 Printers Alley', 'Nashville, TN 37201']},
#    'phone': '+16159222757',
#    'display_phone': '(615) 922-2757',
#    'distance': 2873.044452670268},
#   {'id': 'YDfQlJKpocV51jCL5Eavrw',
#    'alias': 'springwater-nashville',
#    'name': 'Springwater',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/w3knsfn2R5UCm28rkrZnGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/springwater-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 71,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.1460722982883,
#     'longitude': -86.8119411170483},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '115 27th Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['115 27th Ave N', 'Nashville, TN 37203']},
#    'phone': '+16153200345',
#    'display_phone': '(615) 320-0345',
#    'distance': 3437.2126423588406},
#   {'id': 'PlXN5XKMoZNu4K34tsQIcw',
#    'alias': 'the-basement-nashville',
#    'name': 'The Basement',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6jxsfEHwW7EyoaGqYgOncQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-basement-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 64,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.13705, 'longitude': -86.77836},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1604 8th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1604 8th Ave S', 'Nashville, TN 37203']},
#    'phone': '+16156459174',
#    'display_phone': '(615) 645-9174',
#    'distance': 277.0749624255337},
#   {'id': '_4LtVmrCdz40l1DnptAmgQ',
#    'alias': 'tin-roof-nashville',
#    'name': 'Tin Roof',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vpbIpGdErLzkPBlbZGuSPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tin-roof-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 194,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 36.153263092041,
#     'longitude': -86.7900543212891},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1516 Demonbreun St',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1516 Demonbreun St', 'Nashville, TN 37203']},
#    'phone': '+16153137103',
#    'display_phone': '(615) 313-7103',
#    'distance': 2170.375365989534},
#   {'id': 'y5HKctZc_3KBOryo_urAWQ',
#    'alias': 'big-machine-brewery-and-distillery-nashville',
#    'name': 'Big Machine Brewery & Distillery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3SRPdBNrD5mmsPb1bkSRHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-machine-brewery-and-distillery-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 33,
#    'categories': [{'alias': 'distilleries', 'title': 'Distilleries'},
#     {'alias': 'karaoke', 'title': 'Karaoke'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.1607805, 'longitude': -86.7752739},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '122 3rd Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['122 3rd Ave S', 'Nashville, TN 37201']},
#    'phone': '+16153454539',
#    'display_phone': '(615) 345-4539',
#    'distance': 2568.3455226155943},
#   {'id': 'zkk_2iqOl0e0guMn4h_AUA',
#    'alias': 'the-back-corner-nashville',
#    'name': 'The Back Corner',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sOc1OxqX9E9S9kTFyC_c-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-back-corner-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 26,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.178599, 'longitude': -86.790599},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1413 5th Ave N',
#     'address2': '',
#     'address3': None,
#     'city': 'Nashville',
#     'zip_code': '37208',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1413 5th Ave N', 'Nashville, TN 37208']},
#    'phone': '+16158216048',
#    'display_phone': '(615) 821-6048',
#    'distance': 4745.333150033164},
#   {'id': 'K59I711q4mFXw7ZBxdwBTg',
#    'alias': 'belcourt-taps-nashville',
#    'name': 'Belcourt Taps',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QJs52Tctzvk3_OFxs4-pAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/belcourt-taps-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 182,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 36.1366251883282,
#     'longitude': -86.8023823478504},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2117 Belcourt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37212',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2117 Belcourt Ave', 'Nashville, TN 37212']},
#    'phone': '+16159153622',
#    'display_phone': '(615) 915-3622',
#    'distance': 2415.891112767151},
#   {'id': '1RerTYaZEAfmSARDhsZ-8Q',
#    'alias': 'the-valentine-nashville',
#    'name': 'The Valentine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4Bmh5Kl5uYhfLQFb8_ZY1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-valentine-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 98,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.1614875793457,
#     'longitude': -86.7767715454102},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '312 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['312 Broadway', 'Nashville, TN 37201']},
#    'phone': '+16292026979',
#    'display_phone': '(629) 202-6979',
#    'distance': 2651.026743248368},
#   {'id': 'dB7-TdEG4llXz9HwpMAZPg',
#    'alias': 'losers-bar-and-grill-downtown-nashville',
#    'name': 'Losers Bar & Grill -Downtown',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WtROeLG3yixtFGTRs8BAhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/losers-bar-and-grill-downtown-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 139,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.1604118347168,
#     'longitude': -86.7770614624023},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '111 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['111 4th Ave', 'Nashville, TN 37201']},
#    'phone': '+16157365050',
#    'display_phone': '(615) 736-5050',
#    'distance': 2530.073931692076},
#   {'id': 'e0kTrMIXTAmmvsmoli45hw',
#    'alias': 'songbird-tours-nashville',
#    'name': 'SongBird Tours',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tam097SFgYGVJkgLSckdGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/songbird-tours-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 15,
#    'categories': [{'alias': 'bustours', 'title': 'Bus Tours'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 36.1566085, 'longitude': -86.778491},
#    'transactions': [],
#    'location': {'address1': '201 5th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['201 5th Ave S', 'Nashville, TN 37203']},
#    'phone': '+16152366094',
#    'display_phone': '(615) 236-6094',
#    'distance': 2119.64686578125},
#   {'id': '35JPTJ69zVoTGuk6TBX5qA',
#    'alias': 'john-richs-redneck-riviera-nashville',
#    'name': "John Rich's Redneck Riviera",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3VmStidwuqfVbwBgr2SVVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/john-richs-redneck-riviera-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 71,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.1617232219295, 'longitude': -86.7757476},
#    'transactions': [],
#    'location': {'address1': '208 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['208 Broadway', 'Nashville, TN 37201']},
#    'phone': '+16154364070',
#    'display_phone': '(615) 436-4070',
#    'distance': 2671.523391227744},
#   {'id': 'Tdp95AviUqzvUd3H2C5xvw',
#    'alias': 'famous-saloon-nashville',
#    'name': 'Famous Saloon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iwxfl1q05zBkK6EdQSB9Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/famous-saloon-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 96,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.16229, 'longitude': -86.775283},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '110 2nd Ave N',
#     'address2': '',
#     'address3': None,
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['110 2nd Ave N', 'Nashville, TN 37201']},
#    'phone': '+16159335000',
#    'display_phone': '(615) 933-5000',
#    'distance': 2734.5406802362168},
#   {'id': '1Rk5z7X6hi0l6YSQ-5NVEA',
#    'alias': 'marathon-music-works-nashville',
#    'name': 'Marathon Music Works',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-AFjYuYCwT0PyuTguPtglA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marathon-music-works-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 98,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.164156, 'longitude': -86.797431},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1402 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1402 Clinton St', 'Nashville, TN 37203']},
#    'phone': '+16158911781',
#    'display_phone': '(615) 891-1781',
#    'distance': 3539.482845427004},
#   {'id': 'DjCCD8xRKAJmM_r-kB1jOA',
#    'alias': 'war-memorial-auditorium-nashville',
#    'name': 'War Memorial Auditorium',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0MCI9dfeXB_-jxzpf_AtAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/war-memorial-auditorium-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 36,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.16448, 'longitude': -86.78313},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '301 6th Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37243',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['301 6th Ave N', 'Nashville, TN 37243']},
#    'phone': '+16157824000',
#    'display_phone': '(615) 782-4000',
#    'distance': 3011.8971458979486},
#   {'id': 'iLBqcyjmrHzCIt5NTDWOBw',
#    'alias': 'wannabs-karaoke-bar-nashville',
#    'name': "WannaB's Karaoke Bar",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/duOwC_5-1YYt_Mkdyx3ORw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wannabs-karaoke-bar-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 85,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'},
#     {'alias': 'karaoke', 'title': 'Karaoke'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.161258, 'longitude': -86.7762672},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '305 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Nashville',
#     'zip_code': '37201',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['305 Broadway', 'Nashville, TN 37201']},
#    'phone': '+13524153812',
#    'display_phone': '(352) 415-3812',
#    'distance': 2620.5856641072705},
#   {'id': 'tewtTBXF-_vNp9Fed97B8w',
#    'alias': 'general-jackson-showboat-nashville',
#    'name': 'General Jackson Showboat',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ubo4HxY2ROz_O5sg4yNRuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/general-jackson-showboat-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 137,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 36.2038876326763,
#     'longitude': -86.6952658276985},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '2812 Opryland Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37214',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['2812 Opryland Dr', 'Nashville, TN 37214']},
#    'phone': '+16154583900',
#    'display_phone': '(615) 458-3900',
#    'distance': 10298.27871401439},
#   {'id': '7NTAlTr6io7t6iMwJbgsVw',
#    'alias': 'dawghouse-saloon-nashville',
#    'name': 'DawgHouse Saloon',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WrihYvv3CdyJ21YLgrwEbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dawghouse-saloon-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 117,
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 36.153147, 'longitude': -86.790335},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1522 Demonbreun St',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1522 Demonbreun St', 'Nashville, TN 37203']},
#    'phone': '+16158647393',
#    'display_phone': '(615) 864-7393',
#    'distance': 2173.071331974416},
#   {'id': 'GOcyHHKE1kBMW9x1-6OwRg',
#    'alias': 'houston-station-nashville',
#    'name': 'Houston Station',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D_McloiZyyl6MXIdoI4IuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/houston-station-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 15,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 36.1431581, 'longitude': -86.7670587},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '434 Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['434 Houston St', 'Nashville, TN 37203']},
#    'phone': '+16152897225',
#    'display_phone': '(615) 289-7225',
#    'distance': 972.0474742200304},
#   {'id': 'vKp-9VW7f9-ZEpWZpVCRJw',
#    'alias': 'the-high-watt-nashville',
#    'name': 'The High Watt',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9y-GibPy7fRreP90VtGxaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-high-watt-nashville?adjust_creative=E6_YOL-L_jehSOPaHYyq0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=E6_YOL-L_jehSOPaHYyq0g',
#    'review_count': 24,
#    'categories': [{'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 36.152824, 'longitude': -86.780319},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1 Cannery Row',
#     'address2': '',
#     'address3': '',
#     'city': 'Nashville',
#     'zip_code': '37203',
#     'country': 'US',
#     'state': 'TN',
#     'display_address': ['1 Cannery Row', 'Nashville, TN 37203']},
#    'phone': '+16152513020',
#    'display_phone': '(615) 251-3020',
#    'distance': 1755.2929818971456}],
#  'total': 90,
#  'region': {'center': {'longitude': -86.7755126953125,
#    'latitude': 36.137698356986476}}}

# %%
def extract_music_info(music):
    categories =  [a['title'] for a in music['categories']]
    ratings = music['rating']
    name = music['name']
    address = music['location']['display_address']
    latitude = music['coordinates']['latitude']
    longitude = music['coordinates']['longitude']
    try:
        price = music['price']
    except:
        price = 'no price'
    zip_code = music['location']['zip_code']
    is_closed = music['is_closed']
    output_dict_music = { 
                   'categories': categories,   
                   'ratings': ratings,
                   'name': name,
                   'display_address': address,
                   'latitude': latitude, 
                   'longitude': longitude, 
                   'price': price, 
                   'zip_code': zip_code,
                   'is_closed': is_closed}

    return output_dict_music

# %%
music_list = []
#for increment in range(0, 1000, 50) : 
#    response_business_music = requests.get(url = business_endpoint, params = params_category_music, headers = header_category)
for music_data in response_business_music.json()['businesses']:
    music_dict = extract_music_info(music_data)
    music_list.append(music_dict)
   # params_offset += 50

# %%
music_venues_nash_top = pd.DataFrame(music_list)
music_venues_nash_top
# Out:
#                                            categories  ratings  \
# 0   [Music Venues, Dive Bars, American (Traditional)]      4.5
# 1                    [Music Venues, Historical Tours]      4.5
# 2             [Cinema, Performing Arts, Music Venues]      4.5
# 3                             [Music Venues, Lounges]      3.5
# 4                                      [Music Venues]      4.5
# 5                [Bars, American (New), Music Venues]      4.0
# 6   [Music Venues, Venues & Event Spaces, Performi...      4.5
